# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt

import pandas as pd

data = pd.read_excel('voice.ods', engine="odf")
data = data.dropna()

print(data)

print('총 샘플의 수 :',len(data))

data['tag'] = data['tag'].replace(['ham','spam'],[0,1])
data.isnull().values.any() # null값을 가진 샘플이 있는지
data['contents'].nunique(), data['tag'].nunique() # 중복된 샘플이 있는지 확인
data.drop_duplicates(subset=['contents'], inplace=True) # contents 열에서 중복인 내용이 있다면 중복 제거

X_data = data['contents']

result = ""
for text in X_data:
    result = result + text
    
wordcloud = WordCloud(font_path='MaruBuri-Regular.ttf', background_color='white').generate(result)

plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show()
# Out:
#     tag                                           contents
# 0  spam  모르는 사람이에요나이는 42세 남성이고. 네 지인들이나 친인척 중에도 없으신가요.네...
# 1  spam  예 수고하십니다. 서울중앙지검에 김용민 수사관이라고 합니다네다름이 아니라 지금 본인...
# 2  spam  여보세요여보세요 예예 맞습니다네 연락드린 곳은 서울중앙지검이고요. 전 형사7부의 김...
# 3  spam  네 여보세요. 네 네 안녕하세요 여기 ok 저축은행입니다. 김찬준 고객님 네. 부결...
# 4  spam  유출 사건 관련해서 몇 가지 확인차 연락을 드렸고요. 혹시 본인께서어디시라고요 어디...
# 5  spam  여보세요 네. 한수희 씨 맞습니까네 맞습니다네. 연락드린 곳은 서울중앙지방검찰청의 ...
# 6  spam  네 그리고 한수희 씨. 현재 중립적인 조사자 신분으로 저희가 조사를 진행을 하고 있...
# 7  spam  예 실례지만 누구십니까예 수고하십니다. 저는 서울중앙지검에 정진우 수사관이고요 다름...
# 8  spam  예. 어플 확인하셔서. 확인되는 내용이 있으신하나은행에 접금하고 있고요네네네돈 불고...
# 9  spam  일단 본인 사건이니까 사건 경위에 대해 설명을 드릴 건데 네이버 카페 중고나라 사이...
# 총 샘플의 수 : 10
